# %%
# !git clone https://github.com/AlexeyAB/darknet
# %cd darknet
# Out:
# c:\Users\Roy\Documents\Project\Object Detection Using YOLO 4\darknet
# Cloning into 'darknet'...
# Updating files:  79% (1639/2058)
# Updating files:  80% (1647/2058)
# Updating files:  81% (1667/2058)
# Updating files:  82% (1688/2058)
# Updating files:  83% (1709/2058)
# Updating files:  84% (1729/2058)
# Updating files:  85% (1750/2058)
# Updating files:  86% (1770/2058)
# Updating files:  87% (1791/2058)
# Updating files:  88% (1812/2058)
# Updating files:  89% (1832/2058)
# Updating files:  90% (1853/2058)
# Updating files:  91% (1873/2058)
# Updating files:  92% (1894/2058)
# Updating files:  93% (1914/2058)
# Updating files:  94% (1935/2058)
# Updating files:  95% (1956/2058)
# Updating files:  96% (1976/2058)
# Updating files:  97% (1997/2058)
# Updating files:  98% (2017/2058)
# Updating files:  99% (2038/2058)
# Updating files: 100% (2058/2058)
# Updating files: 100% (2058/2058), done.

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/g' Makefile
# Out:
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.
# 'sed' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !make
# Out:
# 'make' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### Download sample video

# %%
# !wget https://sites of your video.mp4

# %%
# import necessary packages
from matplotlib import pyplot as plt
import cv2

def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# !python3 darknet_images.py --input data/horses.jpg --weights yolov4.weights --config_file cfg/yolov4.cfg --dont_show
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Roy\Documents\Project\Object Detection Using YOLO 4\darknet\darknet_images.py", line 8, in <module>
#     import darknet
#   File "c:\Users\Roy\Documents\Project\Object Detection Using YOLO 4\darknet\darknet.py", line 240, in <module>
#     lib = CDLL("darknet.dll", RTLD_GLOBAL)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ctypes\__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# FileNotFoundError: Could not find module 'darknet.dll' (or one of its dependencies). Try using the full path with constructor syntax.

# %%
image = cv2.imread("data/horses.jpg")
plt_imshow("input image", image)

# %%
image = cv2.imread("output_0.png")
plt_imshow("output", image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 2
#       1 image = cv2.imread("output_0.png")
# ----> 2 plt_imshow("output", image)
#
# Cell In[6], line 7, in plt_imshow(title, image)
#       5 def plt_imshow(title, image):
#       6 	# convert the image frame BGR to RGB color space and display it
# ----> 7 	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       8 	plt.imshow(image)
#       9 	plt.title(title)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
# !python darknet_video.py --input /content/Road.mp4 --weights yolov4.weights --config_file cfg/yolov4.cfg --dont_show --out_filename /content/output.mp4
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Roy\Documents\Project\Object Detection Using YOLO 4\darknet\darknet_video.py", line 6, in <module>
#     import darknet
#   File "c:\Users\Roy\Documents\Project\Object Detection Using YOLO 4\darknet\darknet.py", line 240, in <module>
#     lib = CDLL("darknet.dll", RTLD_GLOBAL)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ctypes\__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# FileNotFoundError: Could not find module 'darknet.dll' (or one of its dependencies). Try using the full path with constructor syntax.
